# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="darkgrid")
df=pd.read_csv(r"C:\Users\Namitha Tresa Joppan\Downloads\istherecorrelation.csv")
print("Data read successfully")
print(df)
x = df['Year'].values
y = df['NL Beer Consumption'].values
plt.figure()
plt.xlabel('Year')
plt.ylabel('Beer Consumption')
plt.plot(x,y)
plt.savefig("plot.png",dpi=300 )
# Out:
# Data read successfully
#     Year  NL Beer Consumption
# 0   2006                11402
# 1   2007                11492
# 2   2008                11450
# 3   2009                11502
# 4   2010                11474
# 5   2011                11480
# 6   2012                11452
# 7   2013                11484
# 8   2014                11555
# 9   2015                11601
# 10  2016                11731
# 11  2017                11862
# 12  2018                12048
